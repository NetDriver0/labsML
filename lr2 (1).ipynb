# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('Electric_Vehicle_Population_Size_History_By_County.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('Electric_Vehicle_Population_Size_History_By_County')
#
# File c:\Users\NetDriver\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
#                 Date          County State Vehicle Primary Use  \
# 0  September 30 2022       Riverside    CA           Passenger
# 1   December 31 2022  Prince William    VA           Passenger
# 2    January 31 2020          Dakota    MN           Passenger
# 3       June 30 2022           Ferry    WA               Truck
# 4       July 31 2021         Douglas    CO           Passenger
#
#   Battery Electric Vehicles (BEVs) Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                7                                        0
# 1                                1                                        2
# 2                                0                                        1
# 3                                0                                        0
# 4                                0                                        1
#
#   Electric Vehicle (EV) Total Non-Electric Vehicle Total Total Vehicles  \
# ...

# %%
print(df.shape)
# Out:
# (20819, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20819 entries, 0 to 20818
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      20819 non-null  object
#  1   County                                    20733 non-null  object
#  2   State                                     20733 non-null  object
#  3   Vehicle Primary Use                       20819 non-null  object
#  4   Battery Electric Vehicles (BEVs)          20819 non-null  object
#  5   Plug-In Hybrid Electric Vehicles (PHEVs)  20819 non-null  object
#  6   Electric Vehicle (EV) Total               20819 non-null  object
#  7   Non-Electric Vehicle Total                20819 non-null  object
#  8   Total Vehicles                            20819 non-null  object
#  9   Percent Electric Vehicles                 20819 non-null  float64
# ...

# %%
#Добавление строки

# %%
diff = {'Date':['September 30 2022', 'January 7 2024', 'March 28 2021'], 
        'County':['Riverside', 'Ferry', 'Douglas'],
        'State':['CA', 'WA', 'CO'],
        'Vehicle Primary Use':['Passenger', 'Passenger', 'Truck'],
        'Battery Electric Vehicles (BEVs)':[0, 1, 7],
        'Plug-In Hybrid Electric Vehicles (PHEVs)':[3, 0, 4],
        'Electric Vehicle (EV) Total':[7, 1, 0],
        'Non-Electric Vehicle Total':[3500, 400, 402],
        'Total Vehicles':[3500, 400, 402],
        'Percent Electric Vehicles':[1, 2, 3]
       } 
  
df2 = pd.DataFrame(diff) 
display(df2)
# Out:
#                 Date     County State Vehicle Primary Use  \
# 0  September 30 2022  Riverside    CA           Passenger
# 1     January 7 2024      Ferry    WA           Passenger
# 2      March 28 2021    Douglas    CO               Truck
#
#    Battery Electric Vehicles (BEVs)  Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                 0                                         3
# 1                                 1                                         0
# 2                                 7                                         4
#
#    Electric Vehicle (EV) Total  Non-Electric Vehicle Total  Total Vehicles  \
# 0                            7                        3500            3500
# 1                            1                         400             400
# 2                            0                         402             402
#
#    Percent Electric Vehicles
# 0                          1
# 1                          2
# ...

# %%
df3 = pd.concat([df, df2], ignore_index = True) 
df3.reset_index() 
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
# 20819  September 30 2022       Riverside    CA           Passenger
# 20820     January 7 2024           Ferry    WA           Passenger
# 20821      March 28 2021         Douglas    CO               Truck
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
#Удаление строки

# %%
df3.drop([20819, 20820, 20821], axis=0, inplace=True)
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
#добавление и удаление повторов

# %%
diff = {'Date':['November 30 2019'], 
        'County':['Goochland'],
        'State':['VA'],
        'Vehicle Primary Use':['Passenger'],
        'Battery Electric Vehicles (BEVs)':[3],
        'Plug-In Hybrid Electric Vehicles (PHEVs)':[1],
        'Electric Vehicle (EV) Total':[4],
        'Non-Electric Vehicle Total':[271],
        'Total Vehicles':[275],
        'Percent Electric Vehicles':[1.45]
       } 
df2 = pd.DataFrame(diff) 
display(df2)
# Out:
#                Date     County State Vehicle Primary Use  \
# 0  November 30 2019  Goochland    VA           Passenger
#
#    Battery Electric Vehicles (BEVs)  Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                 3                                         1
#
#    Electric Vehicle (EV) Total  Non-Electric Vehicle Total  Total Vehicles  \
# 0                            4                         271             275
#
#    Percent Electric Vehicles
# 0                       1.45

# %%
df3 = pd.concat([df, df2, df2], ignore_index = True) 
df3.reset_index() 
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
# 20819   November 30 2019       Goochland    VA           Passenger
# 20820   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
df3.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20816    False
# 20817    False
# 20818    False
# 20819    False
# 20820     True
# Length: 20821, dtype: bool

# %%
df3.drop_duplicates(subset=None, keep="first", inplace=True)
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
# 20819   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
#удаление столбца

# %%
df3 = df3.drop(['Battery Electric Vehicles (BEVs)', 'Plug-In Hybrid Electric Vehicles (PHEVs)'], axis=1)

# %%
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
# 20819   November 30 2019       Goochland    VA           Passenger
#
#       Electric Vehicle (EV) Total Non-Electric Vehicle Total Total Vehicles  \
# 0                               7                        460            467
# ...

# %%
#пустые значения

# %%
df3 = df.copy()

# %%
df3.isna().any()
# Out:
# Date                                        False
# County                                       True
# State                                        True
# Vehicle Primary Use                         False
# Battery Electric Vehicles (BEVs)            False
# Plug-In Hybrid Electric Vehicles (PHEVs)    False
# Electric Vehicle (EV) Total                 False
# Non-Electric Vehicle Total                  False
# Total Vehicles                              False
# Percent Electric Vehicles                   False
# dtype: bool

# %%
df3[df3.isnull().any(axis=1)]
# Out:
#                     Date County State Vehicle Primary Use  \
# 112         June 30 2020    NaN   NaN           Passenger
# 466      January 31 2022    NaN   NaN           Passenger
# 526        April 30 2023    NaN   NaN           Passenger
# 718        March 31 2019    NaN   NaN           Passenger
# 1031       March 31 2020    NaN   NaN           Passenger
# ...                  ...    ...   ...                 ...
# 19164   November 30 2018    NaN   NaN           Passenger
# 19710       June 30 2019    NaN   NaN           Passenger
# 20130    October 31 2022    NaN   NaN           Passenger
# 20323        May 31 2019    NaN   NaN           Passenger
# 20353  September 30 2022    NaN   NaN           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 112                                  6
# 466                                  5
# 526                                  5
# 718                                  5
# 1031                                 7
# ...

# %%
#заполнение значениями

# %%
df3.isna().any()
# Out:
# Date                                        False
# County                                       True
# State                                        True
# Vehicle Primary Use                         False
# Battery Electric Vehicles (BEVs)            False
# Plug-In Hybrid Electric Vehicles (PHEVs)    False
# Electric Vehicle (EV) Total                 False
# Non-Electric Vehicle Total                  False
# Total Vehicles                              False
# Percent Electric Vehicles                   False
# dtype: bool

# %%
df3[df3.isnull().any(axis=1)]
# Out:
#                     Date County State Vehicle Primary Use  \
# 112         June 30 2020    NaN   NaN           Passenger
# 466      January 31 2022    NaN   NaN           Passenger
# 526        April 30 2023    NaN   NaN           Passenger
# 718        March 31 2019    NaN   NaN           Passenger
# 1031       March 31 2020    NaN   NaN           Passenger
# ...                  ...    ...   ...                 ...
# 19164   November 30 2018    NaN   NaN           Passenger
# 19710       June 30 2019    NaN   NaN           Passenger
# 20130    October 31 2022    NaN   NaN           Passenger
# 20323        May 31 2019    NaN   NaN           Passenger
# 20353  September 30 2022    NaN   NaN           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 112                                  6
# 466                                  5
# 526                                  5
# 718                                  5
# 1031                                 7
# ...

# %%
df3 = df3.fillna('CA')

# %%
df3[df3.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, County, State, Vehicle Primary Use, Battery Electric Vehicles (BEVs), Plug-In Hybrid Electric Vehicles (PHEVs), Electric Vehicle (EV) Total, Non-Electric Vehicle Total, Total Vehicles, Percent Electric Vehicles]
# Index: []

# %%
df3 = df.copy()

# %%
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
#добавление нового столбца

# %%
df3['check Percent >3'] = (df3['Percent Electric Vehicles']>=3)

# %%
display(df3)
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# ...

# %%
#Фильтрация

# %%
df4 = df3[(df3['check Percent >3']==True) & (df3['Vehicle Primary Use']!='Passenger') & (df3['State']=='OH')]

# %%
display(df4)
# Out:
#                     Date    County State Vehicle Primary Use  \
# 166        March 31 2023  Hamilton    OH               Truck
# 180       August 31 2023  Hamilton    OH               Truck
# 2019     October 31 2022  Hamilton    OH               Truck
# 2352     January 31 2023  Hamilton    OH               Truck
# 8559         May 31 2023  Hamilton    OH               Truck
# 9335   September 30 2023  Hamilton    OH               Truck
# 10456      April 30 2023  Hamilton    OH               Truck
# 10534   November 30 2022  Hamilton    OH               Truck
# 14395   February 28 2023  Hamilton    OH               Truck
# 16913       July 31 2023  Hamilton    OH               Truck
# 17833       June 30 2023  Hamilton    OH               Truck
# 19841   December 31 2022  Hamilton    OH               Truck
#
#       Battery Electric Vehicles (BEVs)  \
# 166                                  1
# 180                                  1
# 2019                                 1
# ...

# %%
#Сортировка

# %%
df3.sort_values(by=["Percent Electric Vehicles"], ascending=[False]).head()
# Out:
#                    Date      County State Vehicle Primary Use  \
# 17347  February 29 2024  Las Animas    CO           Passenger
# 4631    October 31 2023         Ray    MO           Passenger
# 4908      April 30 2022      Sevier    AR           Passenger
# 1892       July 31 2023  Las Animas    CO           Passenger
# 11276     March 31 2021      Sevier    AR           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 17347                                1
# 4631                                 0
# 4908                                 0
# 1892                                 1
# 11276                                0
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 17347                                        0                           1
# 4631                                         1                           1
# 4908                                         1                           1
# ...

# %%
#Построение гистограммы

# %%
sns.countplot(x="Vehicle Primary Use", hue="Percent Electric Vehicles", data=df);

# %%
#График ядерной оценки плотности

# %%
features = ["Total Vehicles", "Percent Electric Vehicles"]
df3[features].hist(figsize=(10, 4));

# %%
df3[features].plot(
    kind="density", subplots=True, layout=(1, 2), sharex=False, figsize=(10, 4)
);

# %%
#Диаграмма рассеивания

# %%
plt.scatter(df3["Total Vehicles"], df3["Percent Electric Vehicles"]);

# %%
#Диаграмма "ящиков с усиками"

# %%
sns.boxplot(x="Total Vehicles", data=df);

# %%
#Получение оценки набора данных

# %%
df3[features].describe()
# Out:
#        Percent Electric Vehicles
# count               20819.000000
# mean                    4.139216
# std                    11.055350
# min                     0.000000
# 25%                     0.390000
# 50%                     1.220000
# 75%                     2.995000
# max                   100.000000
