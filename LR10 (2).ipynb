# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
money_extractor = MoneyExtractor(morph_vocab)
addr_extractor = AddrExtractor(morph_vocab)

# %%
# Получаем HTML-код страницы
text = ''
doc = Doc(text)
doc

# %%
# Используем BeautifulSoup для парсинга HTML
soup = BeautifulSoup(html, "html.parser")

# %%
# Извлекаем текст из HTML
text = soup.get_text()

# %%
# Создаем объект NamesExtractor для извлечения имен и отчеств
morph_vocab = MorphVocab()
extractor = NamesExtractor(morph_vocab)

# %%
# Извлекаем имена и отчества из текста
matches = extractor(text)

# %%
# Создаем множество для хранения уникальных имен и отчеств
unique_names = set()

# %%
# Обходим полученные совпадения и добавляем их в множество уникальных имен
for match in matches:
    name = match.fact.first
    surname = match.fact.last
    unique_names.add((name, surname))

# %%
# Выводим уникальные имена и отчества
for name, surname in unique_names:
    print(f"Имя: {name}, Отчество: {surname}")
# Out:
# Имя: None, Отчество: боевой
# Имя: None, Отчество: дружиной
# Имя: None, Отчество: Белорусская
# Имя: None, Отчество: Иордан
# Имя: None, Отчество: колхозах
# Имя: None, Отчество: Земского
# Имя: None, Отчество: уже
# Имя: None, Отчество: Горбачева
# Имя: Анна, Отчество: Ивановна
# Имя: None, Отчество: мелкие
# Имя: Иваном, Отчество: IV
# Имя: None, Отчество: Желтыми
# Имя: None, Отчество: права
# Имя: None, Отчество: Пять
# Имя: None, Отчество: левый
# Имя: None, Отчество: Походами
# Имя: None, Отчество: сильно
# Имя: None, Отчество: поводом
# Имя: None, Отчество: восточных
# Имя: None, Отчество: быту
# Имя: None, Отчество: Город
# Имя: None, Отчество: слабы
# Имя: None, Отчество: всесильный
# Имя: None, Отчество: Новгородско
# Имя: None, Отчество: полка
# Имя: Галицию, Отчество: None
# Имя: None, Отчество: Клин
# Имя: None, Отчество: Новгорода
# Имя: Александра, Отчество: Правительство
# Имя: None, Отчество: Великой
# Имя: None, Отчество: концов
# Имя: None, Отчество: дружинников
# ...
